# %%
import pandas as pd

# %% [markdown]
# ## Mean Fold Condition Analysis

# %%
mean_rule_elements_df = pd.DataFrame()
with open("../../Data/explainability/mean_acc_fold/mean_rulebase.txt", "r") as f:
    lines = f.readlines()
    max_rule_length = 0
    
    for rule in lines:
        rule_number = int(rule.split(':')[0].split()[1])
        rule_result = int(rule.split(' THEN ')[-1].split('\n')[0].split()[-1])
        rule_stem = rule.split(' IF ')[1].split(' AND')[0]
        rule_pieces = ', '.join(rule.split(' AND ')[1:]).split('\n')[0].split(' THEN ')[0]
        rule_pieces = rule_stem + ', ' + rule_pieces
        rule_pieces_list = rule_pieces.split(', ')

        rule_length = len(rule_pieces_list)
        max_rule_length = max(max_rule_length, rule_length)

        row_data = {
            'Rule': [rule_number], 
            'Rule Length': [rule_length], 
            'Rule Piece 1': [rule_stem], 
            'Rule Pieces': [rule_pieces],
            'Rule Decision': [rule_result]
        }

        # Add rule pieces dynamically
        for i, piece in enumerate(rule_pieces_list):
            row_data[f'Rule Piece {i+1}'] = [piece]

        row = pd.DataFrame(row_data)
        mean_rule_elements_df = pd.concat([mean_rule_elements_df, row], axis=0, ignore_index=True)

column_order = ['Rule', 'Rule Length', 'Rule Decision', 'Rule Piece 1'] + \
               [f'Rule Piece {i+1}' for i in range(1, max_rule_length)]

mean_rule_elements_df = mean_rule_elements_df.reindex(columns=column_order)

# %%
mean_rule_acc_df = pd.read_csv('../../Data/explainability/mean_acc_fold/mean_rule_results.csv')

# %%
mean_rule_analysis_df = pd.merge(mean_rule_acc_df, mean_rule_elements_df, on=['Rule', 'Rule Decision'], how='right')
mean_rule_analysis_df = mean_rule_analysis_df.fillna(0)
mean_rule_analysis_df['#Times_Used'] = mean_rule_analysis_df['#Times_Used'].astype(int)
mean_rule_analysis_df = mean_rule_analysis_df.sort_values(by=['Accuracy', '#Times_Used'], ascending=[False, False], ignore_index=True)

# %%
mean_rule_analysis_df.to_csv('../../Data/explainability/mean_acc_fold/mean_condition_analysis.csv', index=False)

# %%
mean_results = []
for col_name in mean_rule_analysis_df.columns[5:]:
    print(col_name)
    for condition in mean_rule_analysis_df[col_name].unique():
        #print(condition)
        condition_df = mean_rule_analysis_df[mean_rule_analysis_df[col_name]==condition]
        condition_total_times_used = sum(condition_df['#Times_Used'])
        condition_accuracies = list(condition_df['Accuracy'])
        condition_times_used = list(condition_df['#Times_Used'])
        #print(len(rule_condition_accuracies), len(rule_condition_times_used))
        i=0
        condition_grade_numerator = 0
        while i < len(condition_accuracies):
            accuracy_times_used = condition_accuracies[i] * condition_times_used[i]
            condition_grade_numerator = condition_grade_numerator + accuracy_times_used
            i += 1
        #print(rule_grade_numerator)
        if condition_total_times_used == 0:
            condition_grade=0
        else:
            condition_grade = condition_grade_numerator / condition_total_times_used
        if condition==0:
            continue
        else:
            print(f"Condition: {condition}, Grade: {condition_grade}, Times Used: {condition_total_times_used}, Condition Weight: {condition_grade*(condition_total_times_used/3238)}")
        # for index, row in condition_df.iterrows():
        #     rule_condition_accuracies.append(row['Accurcay'])
        #     rule_condition_times_used.append(row['#Times_Used'])
        #     rule
        condition_incorrect = round(condition_total_times_used - (condition_grade*condition_total_times_used))
        condition_weight = condition_grade*(condition_total_times_used/3238)
        condition_score = condition_weight * condition_grade
        mean_results.append({
            "Rule Piece": col_name,
            "Condition": condition,
            "Grade": condition_grade,
            "Times Used": condition_total_times_used,
            "Condition Weight": condition_weight,
            "Times Incorrect": condition_incorrect,
            'Condition Score': condition_score
        })
    

mean_results_df = pd.DataFrame(mean_results).sort_values(by='Condition Score', ascending=False, ignore_index=True)
mean_results_df.to_csv('../../Data/explainability/mean_acc_fold/mean_piece_grades.csv', index=False)
# Out:
# Rule Piece 1
# Condition: defenders_in_box <= 2.50, Grade: 0.9470752089721448, Times Used: 359, Condition Weight: 0.10500308833261271
# Condition: defenders_in_box > 2.50, Grade: 0.5237929837415769, Times Used: 2879, Condition Weight: 0.46571958004694247
# Rule Piece 2
# Condition: yardline_100 > 34.50, Grade: 0.948000000084, Times Used: 250, Condition Weight: 0.07319332922205066
# Condition: yardline_100 <= 34.50, Grade: 0.944954128440367, Times Used: 109, Condition Weight: 0.03180975911056207
# Condition: game_seconds_remaining > 2387.50, Grade: 0.5121951220555555, Times Used: 738, Condition Weight: 0.11673872763341568
# Condition: game_seconds_remaining <= 2387.50, Grade: 0.527790752038767, Times Used: 2141, Condition Weight: 0.3489808524135269
# Rule Piece 3
# Condition: offensive_predictability > 0.02, Grade: 0.9389671362488263, Times Used: 213, Condition Weight: 0.06176652255126622
# Condition: DefenseTeam <= 22.50, Grade: 1.0, Times Used: 80, Condition Weight: 0.02470660901791229
# Condition: AWAY_day_since_last_game <= 7.50, Grade: 0.47985348007509154, Times Used: 546, Condition Weight: 0.0809141445710315
# Condition: offensive_predictability <= 0.02, Grade: 1.0, Times Used: 37, Condition Weight: 0.011426806670784434
# Condition: epa <= 0.47, Grade: 0.4942279944588745, Times Used: 1386, Condition Weight: 0.21155033981470045
# Condition: AWAY_day_since_last_game > 7.50, Grade: 0.6041666664374999, Times Used: 192, Condition Weight: 0.03582458306238419
# Condition: DefenseTeam > 22.50, Grade: 0.7931034482758621, Times Used: 29, Condition Weight: 0.0071031500926497845
# Condition: epa > 0.47, Grade: 0.5894039732384107, Times Used: 755, Condition Weight: 0.13743051259882644
# Rule Piece 4
# Condition: HOME_day_since_last_game > 6.50, Grade: 0.98125, Times Used: 160, Condition Weight: 0.04848672019765287
# Condition: Temperature > 71.72, Grade: 0.5534351145648855, Times Used: 262, Condition Weight: 0.04478072884990735
# Condition: run_count > 54.50, Grade: 0.6857142857142857, Times Used: 35, Condition Weight: 0.007411982705373688
# Condition: run_count <= 54.50, Grade: 0.489267209711325, Times Used: 1351, Condition Weight: 0.20413835710932676
# Condition: Temperature <= 91.24, Grade: 0.6236559137419355, Times Used: 186, Condition Weight: 0.03582458306238419
# Condition: Precipitation <= 0.00, Grade: 0.7692307692307693, Times Used: 26, Condition Weight: 0.0061766522544780735
# Condition: DefenseTeam <= 29.50, Grade: 0.6374442790653789, Times Used: 673, Condition Weight: 0.1324891908001853
# Condition: HOME_day_since_last_game <= 6.50, Grade: 0.8113207551132076, Times Used: 53, Condition Weight: 0.01327980235361334
# Condition: Precipitation > 0.00, Grade: 1.0, Times Used: 3, Condition Weight: 0.0009264978381717109
# Condition: Temperature <= 71.72, Grade: 0.41197183135563376, Times Used: 284, Condition Weight: 0.03613341572112414
# Condition: DefenseTeam > 29.50, Grade: 0.19512195102439026, Times Used: 82, Condition Weight: 0.004941321798641137
# Condition: Temperature > 91.24, Grade: 0.0, Times Used: 6, Condition Weight: 0.0
# Rule Piece 5
# Condition: epa <= 1.46, Grade: 1.0, Times Used: 156, Condition Weight: 0.04817788758492897
# Condition: game_seconds_remaining > 2791.00, Grade: 0.6934306570875913, Times Used: 137, Condition Weight: 0.029339098215256338
# Condition: game_seconds_remaining > 44.00, Grade: 0.8888888888888888, Times Used: 27, Condition Weight: 0.0074119827053736875
# Condition: play_type > 7.50, Grade: 0.5805168989264414, Times Used: 503, Condition Weight: 0.0901791229647931
# Condition: OffenseTeam <= 6.50, Grade: 0.875, Times Used: 24, Condition Weight: 0.006485484867201977
# Condition: Temperature <= 74.96, Grade: 1.0, Times Used: 20, Condition Weight: 0.006176652254478073
# Condition: OffenseTeam > 6.50, Grade: 0.5864197528148148, Times Used: 162, Condition Weight: 0.02933909819518221
# Condition: home_team_on_defense > 76.50, Grade: 0.7466666666666667, Times Used: 75, Condition Weight: 0.017294626312538607
# Condition: Temperature > 35.40, Grade: 0.8039215690392156, Times Used: 51, Condition Weight: 0.012662137128165534
# Condition: game_seconds_remaining <= 1860.50, Grade: 1.0, Times Used: 3, Condition Weight: 0.0009264978381717109
# Condition: Temperature <= 35.40, Grade: 1.0, Times Used: 2, Condition Weight: 0.0006176652254478073
# Condition: epa > 1.46, Grade: 0.25, Times Used: 4, Condition Weight: 0.00030883261272390367
# Condition: game_seconds_remaining <= 2791.00, Grade: 0.39999999995999996, Times Used: 125, Condition Weight: 0.015441630634651019
# Condition: home_team_on_defense <= 76.50, Grade: 0.6237458190819398, Times Used: 598, Condition Weight: 0.1151945644876467
# Condition: yardline_100 > 34.50, Grade: 0.5246636776008968, Times Used: 223, Condition Weight: 0.03613341572112415
# Condition: play_type <= 7.50, Grade: 0.43514150962264153, Times Used: 848, Condition Weight: 0.11395923414453366
# Condition: rest_differential <= 5.00, Grade: 0.19512195102439026, Times Used: 82, Condition Weight: 0.004941321798641137
# Condition: yardline_100 <= 34.50, Grade: 0.0, Times Used: 61, Condition Weight: 0.0
# Condition: game_seconds_remaining <= 44.00, Grade: 0.0, Times Used: 8, Condition Weight: 0.0
# Condition: Temperature > 74.96, Grade: 0.0, Times Used: 6, Condition Weight: 0.0
# Condition: game_seconds_remaining > 1860.50, Grade: 0, Times Used: 0, Condition Weight: 0.0
# Condition: rest_differential > 5.00, Grade: 0, Times Used: 0, Condition Weight: 0.0
# Rule Piece 6
# Condition: offensive_predictability <= 0.10, Grade: 1.0, Times Used: 84, Condition Weight: 0.025941939468807906
# Condition: offensive_predictability > 0.10, Grade: 1.0, Times Used: 72, Condition Weight: 0.022235948116121063
# Condition: AWAY_day_since_last_game <= 5.00, Grade: 1.0, Times Used: 44, Condition Weight: 0.013588634959851761
# Condition: epa <= 0.18, Grade: 1.0, Times Used: 24, Condition Weight: 0.0074119827053736875
# Condition: AWAY_day_since_last_game > 12.50, Grade: 1.0, Times Used: 23, Condition Weight: 0.007103150092649784
# Condition: game_seconds_remaining <= 3455.50, Grade: 1.0, Times Used: 21, Condition Weight: 0.006485484867201977
# Condition: run_count > 14.50, Grade: 1.0, Times Used: 14, Condition Weight: 0.004323656578134651
# Condition: is_close_game <= 0.50, Grade: 1.0, Times Used: 11, Condition Weight: 0.0033971587399629403
# Condition: season_progression <= 0.26, Grade: 1.0, Times Used: 4, Condition Weight: 0.0012353304508956147
# Condition: OffenseTeam > 21.50, Grade: 1.0, Times Used: 1, Condition Weight: 0.00030883261272390367
# Condition: YardsToGo <= 7.50, Grade: 0.9111111109999999, Times Used: 45, Condition Weight: 0.012662137120135884
# Condition: season_progression > 0.26, Grade: 0.787234043, Times Used: 47, Condition Weight: 0.01142680667726992
# Condition: is_close_game > 0.50, Grade: 0.703125, Times Used: 64, Condition Weight: 0.013897467572575664
# Condition: stadium > 12.50, Grade: 0.68869936, Times Used: 469, Condition Weight: 0.09975293386040766
# Condition: AWAY_day_since_last_game <= 12.50, Grade: 0.560416667, Times Used: 480, Condition Weight: 0.0830759728721433
# Condition: AWAY_day_since_last_game > 5.00, Grade: 0.548387097, Times Used: 93, Condition Weight: 0.015750463255404572
# Condition: run_count <= 14.50, Grade: 0.547297297, Times Used: 148, Condition Weight: 0.025015441617047558
# Condition: pass_run_ratio <= 0.69, Grade: 0.544186047, Times Used: 215, Condition Weight: 0.03613341572112415
# Condition: surface_type <= 3.50, Grade: 0.44138756, Times Used: 836, Condition Weight: 0.11395923414453366
# Condition: stadium <= 12.50, Grade: 0.387596899, Times Used: 129, Condition Weight: 0.015441630627239036
# Condition: home_team_on_offense <= 74.50, Grade: 0.197530864, Times Used: 81, Condition Weight: 0.004941321798641137
# Condition: YardsToGo > 7.50, Grade: 0.1125, Times Used: 80, Condition Weight: 0.002779493514515133
# Condition: roof > 1.50, Grade: 0.0, Times Used: 36, Condition Weight: 0.0
# Condition: roof <= 1.50, Grade: 0.0, Times Used: 25, Condition Weight: 0.0
# Condition: surface_type > 3.50, Grade: 0.0, Times Used: 12, Condition Weight: 0.0
# Condition: pass_run_ratio > 0.69, Grade: 0.0, Times Used: 8, Condition Weight: 0.0
# Condition: OffenseTeam <= 21.50, Grade: 0.0, Times Used: 3, Condition Weight: 0.0
# Condition: epa > 0.18, Grade: 0.0, Times Used: 3, Condition Weight: 0.0
# Condition: game_seconds_remaining > 3455.50, Grade: 0.0, Times Used: 3, Condition Weight: 0.0
# Condition: home_team_on_offense > 74.50, Grade: 0.0, Times Used: 1, Condition Weight: 0.0

# %%
rule_condition_cols = [col for col in mean_rule_analysis_df.columns if 'Rule Piece' in col]

# Melt df to get conditions in one column
mean_rule_analysis_df_melted = mean_rule_analysis_df.melt(id_vars=['Rule'], value_vars=rule_condition_cols, 
                      var_name='Rule Piece', value_name='Condition')

# Drop any missing conditions
mean_rule_analysis_df_melted = mean_rule_analysis_df_melted.dropna(subset=['Condition'])

# Merge with results on the condition
df_combined = mean_rule_analysis_df_melted.merge(mean_results_df[['Condition', 'Condition Score']], on='Condition', how='left')

# Now group by Rule and sum the Rule Scores
mean_rule_scores = df_combined.groupby('Rule')['Condition Score'].sum().reset_index()
mean_rule_scores.rename(columns={'Condition Score': 'Total Rule Score'}, inplace=True)

mean_rule_scores.to_csv('../../Data/explainability/mean_acc_fold/mean_rule_scores.csv', index=False)

# %%
#getting average condition score per condition (regardless of branch condition is on)
mean_condition_rankings = mean_results_df.groupby(['Condition']).agg({'Condition Score': 'mean'}).reset_index().sort_values(by='Condition Score', ascending=False, ignore_index=True)
mean_feature_rankings = mean_condition_rankings.copy()
mean_feature_rankings['Feature'] = mean_feature_rankings['Condition'].str.split().str[0]
mean_feature_rankings['comparison operator'] = mean_feature_rankings['Condition'].str.split().str[1]
mean_feature_rankings['threshold'] = mean_feature_rankings['Condition'].str.split().str[-1].astype(float)
mean_feature_rankings = mean_feature_rankings[['Feature', 'comparison operator', 'threshold', 'Condition Score']]
mean_feature_rankings = mean_feature_rankings.groupby('Feature').agg({'Condition Score' : 'mean'}).reset_index().sort_values(by='Condition Score', ascending=False, ignore_index=True)
mean_feature_rankings = mean_feature_rankings.rename(columns={'Condition Score' : 'Mean Fold Feature Score'})
feature_scores_total = mean_feature_rankings['Mean Fold Feature Score'].sum()
# mean_feature_rankings['Feature Score Normalised'] = mean_feature_rankings['Feature Score'] / feature_scores_total
mean_feature_rankings
# Out:
#                      Feature  Mean Fold Feature Score
# 0           defenders_in_box                 0.171693
# 1                  play_type                 0.050969
# 2       home_team_on_defense                 0.042383
# 3                        epa                 0.040204
# 4                    stadium                 0.037342
# 5                  run_count                 0.030744
# 6               yardline_100                 0.029601
# 7   offensive_predictability                 0.029400
# 8   HOME_day_since_last_game                 0.029176
# 9                DefenseTeam                 0.028940
# 10    game_seconds_remaining                 0.028450
# 11              surface_type                 0.025150
# 12  AWAY_day_since_last_game                 0.022726
# 13               Temperature                 0.009873
# 14            pass_run_ratio                 0.009832
# 15             is_close_game                 0.006584
# 16                 YardsToGo                 0.005925
# 17               OffenseTeam                 0.005797
# 18        season_progression                 0.005115
# 19             Precipitation                 0.002839
# 20      home_team_on_offense                 0.000488
# 21         rest_differential                 0.000482
# 22                      roof                 0.000000

# %% [markdown]
# ## Max Fold condition analysis

# %%
max_rule_elements_df = pd.DataFrame()
with open("../../Data/explainability/max_acc_fold/max_rulebase.txt", "r") as f:
    lines = f.readlines()
    max_rule_length = 0
    
    for rule in lines:
        rule_number = int(rule.split(':')[0].split()[1])
        rule_result = int(rule.split(' THEN ')[-1].split('\n')[0].split()[-1])
        rule_stem = rule.split(' IF ')[1].split(' AND')[0]
        rule_pieces = ', '.join(rule.split(' AND ')[1:]).split('\n')[0].split(' THEN ')[0]
        rule_pieces = rule_stem + ', ' + rule_pieces
        rule_pieces_list = rule_pieces.split(', ')

        rule_length = len(rule_pieces_list)
        max_rule_length = max(max_rule_length, rule_length)

        row_data = {
            'Rule': [rule_number], 
            'Rule Length': [rule_length], 
            'Rule Piece 1': [rule_stem], 
            'Rule Pieces': [rule_pieces],
            'Rule Decision': [rule_result]
        }

        # Add rule pieces dynamically
        for i, piece in enumerate(rule_pieces_list):
            row_data[f'Rule Piece {i+1}'] = [piece]

        row = pd.DataFrame(row_data)
        max_rule_elements_df = pd.concat([max_rule_elements_df, row], axis=0, ignore_index=True)

column_order = ['Rule', 'Rule Length', 'Rule Decision', 'Rule Piece 1'] + \
               [f'Rule Piece {i+1}' for i in range(1, max_rule_length)]

max_rule_elements_df = max_rule_elements_df.reindex(columns=column_order)

# %%
max_rule_acc_df = pd.read_csv('../../Data/explainability/max_acc_fold/max_rule_results.csv')

# %%
max_rule_analysis_df = pd.merge(max_rule_acc_df, max_rule_elements_df, on=['Rule', 'Rule Decision'], how='right')
max_rule_analysis_df = max_rule_analysis_df.fillna(0)
max_rule_analysis_df['#Times_Used'] = max_rule_analysis_df['#Times_Used'].astype(int)
max_rule_analysis_df = max_rule_analysis_df.sort_values(by=['Accuracy', '#Times_Used'], ascending=[False, False], ignore_index=True)

# %%
max_rule_analysis_df.to_csv('../../Data/explainability/max_acc_fold/max_condition_analysis.csv', index=False)

# %%
max_results = []
for col_name in max_rule_analysis_df.columns[5:]:
    print(col_name)
    for condition in max_rule_analysis_df[col_name].unique():
        #print(condition)
        condition_df = max_rule_analysis_df[max_rule_analysis_df[col_name]==condition]
        condition_total_times_used = sum(condition_df['#Times_Used'])
        condition_accuracies = list(condition_df['Accuracy'])
        condition_times_used = list(condition_df['#Times_Used'])
        #print(len(rule_condition_accuracies), len(rule_condition_times_used))
        i=0
        condition_grade_numerator = 0
        while i < len(condition_accuracies):
            accuracy_times_used = condition_accuracies[i] * condition_times_used[i]
            condition_grade_numerator = condition_grade_numerator + accuracy_times_used
            i += 1
        #print(rule_grade_numerator)
        if condition_total_times_used == 0:
            condition_grade=0
        else:
            condition_grade = condition_grade_numerator / condition_total_times_used
        if condition==0:
            continue
        else:
            print(f"Condition: {condition}, Grade: {condition_grade}, Times Used: {condition_total_times_used}, Condition Weight: {condition_grade*(condition_total_times_used/3238)}")
        # for index, row in condition_df.iterrows():
        #     rule_condition_accuracies.append(row['Accurcay'])
        #     rule_condition_times_used.append(row['#Times_Used'])
        #     rule
        condition_incorrect = round(condition_total_times_used - (condition_grade*condition_total_times_used))
        condition_weight = condition_grade*(condition_total_times_used/3238)
        condition_score = condition_weight * condition_grade
        max_results.append({
            "Rule Piece": col_name,
            "Condition": condition,
            "Grade": condition_grade,
            "Times Used": condition_total_times_used,
            "Condition Weight": condition_weight,
            "Times Incorrect": condition_incorrect,
            'Condition Score': condition_score
        })
    

max_results_df = pd.DataFrame(max_results).sort_values(by='Condition Score', ascending=False, ignore_index=True)
max_results_df.to_csv('../../Data/explainability/max_acc_fold/max_piece_grades.csv', index=False)
# Out:
# Rule Piece 1
# Condition: defenders_in_box > 2.50, Grade: 0.6494133882774327, Times Used: 2898, Condition Weight: 0.5812229769079679
# Condition: defenders_in_box <= 2.50, Grade: 0.7735294115823529, Times Used: 340, Condition Weight: 0.08122297712723904
# Rule Piece 2
# Condition: game_seconds_remaining > 1510.50, Grade: 0.6811397555488469, Times Used: 1474, Condition Weight: 0.3100679430756641
# Condition: yardline_100 > 33.50, Grade: 0.9073170731707317, Times Used: 205, Condition Weight: 0.057442865966646085
# Condition: game_seconds_remaining <= 1510.50, Grade: 0.6165730333911518, Times Used: 1424, Condition Weight: 0.27115503383230394
# Condition: yardline_100 <= 33.50, Grade: 0.5703703699111111, Times Used: 135, Condition Weight: 0.02378011116059296
# Rule Piece 3
# Condition: epa <= 0.98, Grade: 0.6647992528450047, Times Used: 1071, Condition Weight: 0.2198888201967264
# Condition: current_defence_rank <= 29.50, Grade: 0.9308510638297872, Times Used: 188, Condition Weight: 0.05404570722668314
# Condition: epa > 0.98, Grade: 0.7245657565310174, Times Used: 403, Condition Weight: 0.09017912287893762
# Condition: offense_formation > 8.50, Grade: 1.0, Times Used: 17, Condition Weight: 0.005250154416306362
# Condition: offense_formation <= 8.50, Grade: 0.6119402981869226, Times Used: 1407, Condition Weight: 0.2659048794159976
# Condition: YardsToGo <= 21.50, Grade: 0.5703703699111111, Times Used: 135, Condition Weight: 0.02378011116059296
# Condition: current_defence_rank > 29.50, Grade: 0.6470588235294118, Times Used: 17, Condition Weight: 0.0033971587399629403
# Condition: YardsToGo > 21.50, Grade: 0, Times Used: 0, Condition Weight: 0.0
# Rule Piece 4
# Condition: HOME_day_since_last_game > 8.07, Grade: 0.90625, Times Used: 160, Condition Weight: 0.044780728844966027
# Condition: Down <= 3.50, Grade: 0.8849557522123894, Times Used: 113, Condition Weight: 0.03088326127239037
# Condition: Down > 3.50, Grade: 1.0, Times Used: 75, Condition Weight: 0.023162445954292774
# Condition: yardline_100 <= 36.50, Grade: 0.7291666666666666, Times Used: 48, Condition Weight: 0.010809141445336626
# Condition: home_team_on_defense <= 51.50, Grade: 0.4776119402089552, Times Used: 134, Condition Weight: 0.01976528721062384
# Condition: yardline_100 > 36.50, Grade: 0.7239436616394366, Times Used: 355, Condition Weight: 0.07936998143360098
# Condition: Precipitation > 0.00, Grade: 0.6666666666666666, Times Used: 9, Condition Weight: 0.0018529956763434219
# Condition: score_differential <= 6.50, Grade: 0.75, Times Used: 8, Condition Weight: 0.0018529956763434219
# Condition: home_team_on_defense > 51.50, Grade: 0.6260801253424981, Times Used: 1273, Condition Weight: 0.24613959220537374
# Condition: score_differential > 6.50, Grade: 0.5555555555555556, Times Used: 9, Condition Weight: 0.0015441630636195184
# Condition: HOME_day_since_last_game <= 8.07, Grade: 0.6223929745301866, Times Used: 911, Condition Weight: 0.17510809135176034
# Condition: Precipitation <= 0.00, Grade: 0.563492063, Times Used: 126, Condition Weight: 0.021927115484249537
# Rule Piece 5
# Condition: score_differential > -3.50, Grade: 0.9611650485436893, Times Used: 103, Condition Weight: 0.03057442865966646
# Condition: rest_differential <= 2.50, Grade: 1.0, Times Used: 97, Condition Weight: 0.029956763434218655
# Condition: DefenseTeam <= 27.50, Grade: 1.0, Times Used: 63, Condition Weight: 0.01945645460160593
# Condition: score_differential <= -3.50, Grade: 0.8070175438596491, Times Used: 57, Condition Weight: 0.014206300185299567
# Condition: pass_count <= 17.50, Grade: 0.9047619047619048, Times Used: 21, Condition Weight: 0.00586781964175417
# Condition: pass_count > 17.50, Grade: 0.5925925925925926, Times Used: 27, Condition Weight: 0.004941321803582458
# Condition: DefenseTeam > 27.50, Grade: 1.0, Times Used: 12, Condition Weight: 0.0037059913526868438
# Condition: current_defence_rank <= 5.50, Grade: 0.6111111111111112, Times Used: 18, Condition Weight: 0.0033971587399629403
# Condition: total_play_count > 89.00, Grade: 1.0, Times Used: 10, Condition Weight: 0.0030883261272390363
# Condition: poor_field_condition > 0.50, Grade: 1.0, Times Used: 6, Condition Weight: 0.0018529956763434219
# Condition: OffenseTeam <= 25.00, Grade: 0.8571428571428571, Times Used: 7, Condition Weight: 0.0018529956763434217
# Condition: epa > 0.16, Grade: 0.6673469382816326, Times Used: 490, Condition Weight: 0.10098826428597898
# Condition: rest_differential > 2.50, Grade: 0.1875, Times Used: 16, Condition Weight: 0.0009264978381717109
# Condition: season_progression > 0.15, Grade: 0.42857142857142855, Times Used: 7, Condition Weight: 0.0009264978381717108
# Condition: current_defence_rank > 5.50, Grade: 0.45689655162068965, Times Used: 116, Condition Weight: 0.016368128470660902
# Condition: season_progression <= 0.15, Grade: 1.0, Times Used: 2, Condition Weight: 0.0006176652254478073
# Condition: total_play_count <= 89.00, Grade: 0.7159420286434782, Times Used: 345, Condition Weight: 0.07628165530636195
# Condition: home_team_on_defense <= 0.50, Grade: 0.764705882, Times Used: 85, Condition Weight: 0.020074119817788758
# Condition: home_team_on_defense > 0.50, Grade: 0.6077481838099273, Times Used: 826, Condition Weight: 0.15503397153397158
# Condition: epa <= 0.16, Grade: 0.6002554275900384, Times Used: 783, Condition Weight: 0.1451513279193947
# Condition: poor_field_condition <= 0.50, Grade: 0.0, Times Used: 3, Condition Weight: 0.0
# Condition: OffenseTeam > 25.00, Grade: 0.0, Times Used: 1, Condition Weight: 0.0
# Rule Piece 6
# Condition: run_count <= 32.50, Grade: 1.0, Times Used: 99, Condition Weight: 0.03057442865966646
# Condition: score_differential > -14.50, Grade: 1.0, Times Used: 89, Condition Weight: 0.027486102532427423
# Condition: score_differential > -12.50, Grade: 1.0, Times Used: 53, Condition Weight: 0.016368128474366892
# Condition: AWAY_day_since_last_game <= 17.00, Grade: 1.0, Times Used: 46, Condition Weight: 0.014206300185299567
# Condition: Down <= 3.50, Grade: 1.0, Times Used: 19, Condition Weight: 0.00586781964175417
# Condition: total_play_count > 69.50, Grade: 1.0, Times Used: 16, Condition Weight: 0.004941321803582459
# Condition: pass_run_ratio > 0.55, Grade: 1.0, Times Used: 11, Condition Weight: 0.0033971587399629403
# Condition: score_differential <= -12.50, Grade: 1.0, Times Used: 10, Condition Weight: 0.0030883261272390363
# Condition: stadium <= 32.50, Grade: 1.0, Times Used: 10, Condition Weight: 0.0030883261272390363
# Condition: score_differential <= -14.50, Grade: 1.0, Times Used: 8, Condition Weight: 0.0024706609017912293
# Condition: Temperature > 36.76, Grade: 1.0, Times Used: 6, Condition Weight: 0.0018529956763434219
# Condition: goal_line_situation > 0.50, Grade: 1.0, Times Used: 4, Condition Weight: 0.0012353304508956147
# Condition: stadium <= 10.00, Grade: 1.0, Times Used: 3, Condition Weight: 0.0009264978381717109
# Condition: week > 13.50, Grade: 1.0, Times Used: 3, Condition Weight: 0.0009264978381717109
# Condition: home_team_on_defense <= 38.50, Grade: 1.0, Times Used: 3, Condition Weight: 0.0009264978381717109
# Condition: game_seconds_remaining <= 2350.00, Grade: 0.791208791, Times Used: 182, Condition Weight: 0.044471896220506485
# Condition: YardsToGo <= 11.50, Grade: 0.764705882, Times Used: 85, Condition Weight: 0.020074119817788758
# Condition: run_count <= 13.50, Grade: 0.744394619, Times Used: 223, Condition Weight: 0.05126621372359482
# Condition: goal_line_situation <= 0.50, Grade: 0.664609053, Times Used: 486, Condition Weight: 0.09975293383508338
# Condition: game_seconds_remaining > 2350.00, Grade: 0.63190184, Times Used: 163, Condition Weight: 0.03180975908585547
# Condition: stadium > 3.50, Grade: 0.625180897, Times Used: 691, Condition Weight: 0.13341568864329834
# Condition: run_count > 13.50, Grade: 0.55721393, Times Used: 603, Condition Weight: 0.10376775781037677
# Condition: home_team_on_defense > 38.50, Grade: 0.442477876, Times Used: 113, Condition Weight: 0.015441630632489193
# Condition: stadium <= 3.50, Grade: 0.4130434780000001, Times Used: 92, Condition Weight: 0.011735639276096357
# Condition: stadium > 10.00, Grade: 0.0, Times Used: 13, Condition Weight: 0.0
# Condition: AWAY_day_since_last_game > 17.00, Grade: 0.0, Times Used: 11, Condition Weight: 0.0
# Condition: total_play_count <= 69.50, Grade: 0.0, Times Used: 11, Condition Weight: 0.0
# Condition: pass_run_ratio <= 0.55, Grade: 0.0, Times Used: 7, Condition Weight: 0.0
# Condition: week <= 13.50, Grade: 0.0, Times Used: 4, Condition Weight: 0.0
# Condition: run_count > 32.50, Grade: 0.0, Times Used: 4, Condition Weight: 0.0
# Condition: home_team_on_offense > 10.50, Grade: 0.0, Times Used: 3, Condition Weight: 0.0
# Condition: Down > 3.50, Grade: 0.0, Times Used: 2, Condition Weight: 0.0
# Condition: Temperature <= 36.76, Grade: 0.0, Times Used: 1, Condition Weight: 0.0
# Condition: home_team_on_offense <= 23.00, Grade: 0.0, Times Used: 1, Condition Weight: 0.0
# Condition: home_team_on_offense <= 10.50, Grade: 0, Times Used: 0, Condition Weight: 0.0
# Condition: home_team_on_offense > 23.00, Grade: 0, Times Used: 0, Condition Weight: 0.0
# Condition: YardsToGo > 11.50, Grade: 0, Times Used: 0, Condition Weight: 0.0
# Condition: stadium > 32.50, Grade: 0, Times Used: 0, Condition Weight: 0.0

# %%
rule_condition_cols = [col for col in max_rule_analysis_df.columns if 'Rule Piece' in col]

# Melt df to get conditions in one column
max_rule_analysis_df_melted = max_rule_analysis_df.melt(id_vars=['Rule'], value_vars=rule_condition_cols, 
                      var_name='Rule Piece', value_name='Condition')

# Drop any missing conditions
max_rule_analysis_df_melted = max_rule_analysis_df_melted.dropna(subset=['Condition'])

# Merge with results on the condition
df_combined = max_rule_analysis_df_melted.merge(max_results_df[['Condition', 'Condition Score']], on='Condition', how='left')

# Now group by Rule and sum the Rule Scores
max_rule_scores = df_combined.groupby('Rule')['Condition Score'].sum().reset_index()
max_rule_scores.rename(columns={'Condition Score': 'Total Rule Score'}, inplace=True)

max_rule_scores.to_csv('../../Data/explainability/max_acc_fold/max_rule_scores.csv', index=False)

# %%
#getting average condition score per condition (regardless of branch condition is on)
max_condition_rankings = max_results_df.groupby(['Condition']).agg({'Condition Score': 'mean'}).reset_index().sort_values(by='Condition Score', ascending=False, ignore_index=True)
max_feature_rankings = max_condition_rankings.copy()
max_feature_rankings['Feature'] = max_feature_rankings['Condition'].str.split().str[0]
max_feature_rankings['comparison operator'] = max_feature_rankings['Condition'].str.split().str[1]
max_feature_rankings['threshold'] = max_feature_rankings['Condition'].str.split().str[-1].astype(float)
max_feature_rankings = max_feature_rankings[['Feature', 'comparison operator', 'threshold', 'Condition Score']]
max_feature_rankings = max_feature_rankings.groupby('Feature').agg({'Condition Score' : 'mean'}).reset_index().sort_values(by='Condition Score', ascending=False, ignore_index=True)
max_feature_rankings = max_feature_rankings.rename(columns={'Condition Score' : 'Max Fold Feature Score'})
feature_scores_total = max_feature_rankings['Max Fold Feature Score'].sum()
# max_feature_rankings['Feature Score Normalised'] = max_feature_rankings['Feature Score'] / feature_scores_total
max_feature_rankings
# Out:
#                      Feature  Max Fold Feature Score
# 0           defenders_in_box                0.220141
# 1     game_seconds_remaining                0.108418
# 2                        epa                0.091511
# 3          offense_formation                0.083984
# 4   HOME_day_since_last_game                0.074784
# 5       home_team_on_defense                0.046812
# 6        goal_line_situation                0.033766
# 7               yardline_100                0.032756
# 8                  run_count                0.031639
# 9           total_play_count                0.015661
# 10      current_defence_rank                0.015515
# 11                   stadium                0.015379
# 12         rest_differential                0.015065
# 13                      Down                0.014090
# 14               DefenseTeam                0.011581
# 15        score_differential                0.011564
# 16                 YardsToGo                0.007229
# 17  AWAY_day_since_last_game                0.007103
# 18             Precipitation                0.006796
# 19                pass_count                0.004119
# 20            pass_run_ratio                0.001699
# 21      poor_field_condition                0.000926
# 22               Temperature                0.000926
# 23               OffenseTeam                0.000794
# 24        season_progression                0.000507
# 25                      week                0.000463
# 26      home_team_on_offense                0.000000

# %% [markdown]
# ## Min Fold Condition analysis

# %%
min_rule_elements_df = pd.DataFrame()
with open("../../Data/explainability/min_acc_fold/min_rulebase.txt", "r") as f:
    lines = f.readlines()
    max_rule_length = 0
    
    for rule in lines:
        rule_number = int(rule.split(':')[0].split()[1])
        rule_result = int(rule.split(' THEN ')[-1].split('\n')[0].split()[-1])
        #print(rule_number,rule_result)
        rule_stem = rule.split(' IF ')[1].split(' AND')[0]
        rule_pieces = ', '.join(rule.split(' AND ')[1:]).split('\n')[0].split(' THEN ')[0]
        rule_pieces = rule_stem + ', ' + rule_pieces
        rule_pieces_list = rule_pieces.split(', ')

        rule_length = len(rule_pieces_list)
        max_rule_length = max(max_rule_length, rule_length)

        row_data = {
            'Rule': [rule_number], 
            'Rule Length': [rule_length], 
            'Rule Piece 1': [rule_stem], 
            'Rule Pieces': [rule_pieces],
            'Rule Decision': [rule_result]
        }

        # Add rule pieces dynamically
        for i, piece in enumerate(rule_pieces_list):
            row_data[f'Rule Piece {i+1}'] = [piece]

        row = pd.DataFrame(row_data)
        min_rule_elements_df = pd.concat([min_rule_elements_df, row], axis=0, ignore_index=True)

column_order = ['Rule', 'Rule Length', 'Rule Decision', 'Rule Piece 1'] + \
               [f'Rule Piece {i+1}' for i in range(1, max_rule_length)]

min_rule_elements_df = min_rule_elements_df.reindex(columns=column_order)

# %%
min_rule_acc_df = pd.read_csv('../../Data/explainability/min_acc_fold/min_rule_results.csv')

# %%
min_rule_analysis_df = pd.merge(min_rule_acc_df, min_rule_elements_df, on=['Rule', 'Rule Decision'], how='right')
min_rule_analysis_df = min_rule_analysis_df.fillna(0)
min_rule_analysis_df['#Times_Used'] = min_rule_analysis_df['#Times_Used'].astype(int)
min_rule_analysis_df = min_rule_analysis_df.sort_values(by=['Accuracy', '#Times_Used'], ascending=[False, False], ignore_index=True)

# %%
min_rule_analysis_df.to_csv('../../Data/explainability/min_acc_fold/min_condition_analysis.csv', index=False)

# %%
min_results = []
for col_name in min_rule_analysis_df.columns[5:]:
    print(col_name)
    for condition in min_rule_analysis_df[col_name].unique():
        #print(condition)
        condition_df = min_rule_analysis_df[min_rule_analysis_df[col_name]==condition]
        condition_total_times_used = sum(condition_df['#Times_Used'])
        condition_accuracies = list(condition_df['Accuracy'])
        condition_times_used = list(condition_df['#Times_Used'])
        #print(len(rule_condition_accuracies), len(rule_condition_times_used))
        i=0
        condition_grade_numerator = 0
        while i < len(condition_accuracies):
            accuracy_times_used = condition_accuracies[i] * condition_times_used[i]
            condition_grade_numerator = condition_grade_numerator + accuracy_times_used
            i += 1
        #print(rule_grade_numerator)
        if condition_total_times_used == 0:
            condition_grade=0
        else:
            condition_grade = condition_grade_numerator / condition_total_times_used
        if condition==0:
            continue
        else:
            print(f"Condition: {condition}, Grade: {condition_grade}, Times Used: {condition_total_times_used}, Condition Weight: {condition_grade*(condition_total_times_used/3238)}")
        # for index, row in condition_df.iterrows():
        #     rule_condition_accuracies.append(row['Accurcay'])
        #     rule_condition_times_used.append(row['#Times_Used'])
        #     rule
        condition_incorrect = round(condition_total_times_used - (condition_grade*condition_total_times_used))
        condition_weight = condition_grade*(condition_total_times_used/3238)
        condition_score = condition_weight * condition_grade
        min_results.append({
            "Rule Piece": col_name,
            "Condition": condition,
            "Grade": condition_grade,
            "Times Used": condition_total_times_used,
            "Condition Weight": condition_weight,
            "Times Incorrect": condition_incorrect,
            'Condition Score': condition_score
        })
    

min_results_df = pd.DataFrame(min_results).sort_values(by='Condition Score', ascending=False, ignore_index=True)
min_results_df.to_csv('../../Data/explainability/min_acc_fold/min_piece_grades.csv', index=False)
# Out:
# Rule Piece 1
# Condition: defenders_in_box <= 2.50, Grade: 0.8095238094677871, Times Used: 357, Condition Weight: 0.0892526250710315
# Condition: defenders_in_box > 2.50, Grade: 0.4140923291426588, Times Used: 2881, Condition Weight: 0.3684373070599135
# Rule Piece 2
# Condition: yardline_100 > 34.50, Grade: 0.7442748090839695, Times Used: 262, Condition Weight: 0.06022235947498456
# Condition: yardline_100 <= 34.50, Grade: 0.9894736842105263, Times Used: 95, Condition Weight: 0.02903026559604694
# Condition: game_seconds_remaining > 2371.00, Grade: 0.3353584444471446, Times Used: 823, Condition Weight: 0.08523780104385421
# Condition: game_seconds_remaining <= 2371.00, Grade: 0.4455782315257531, Times Used: 2058, Condition Weight: 0.28319950601605925
# Rule Piece 3
# Condition: current_defence_rank <= 27.50, Grade: 0.77083333325, Times Used: 240, Condition Weight: 0.05713403334774553
# Condition: Precipitation <= 0.00, Grade: 1.0, Times Used: 81, Condition Weight: 0.025015441630636195
# Condition: OffenseTeam > 25.50, Grade: 0.2862903223790323, Times Used: 248, Condition Weight: 0.02192711548795553
# Condition: OffenseTeam <= 25.50, Grade: 0.35652173883478255, Times Used: 575, Condition Weight: 0.0633106855558987
# Condition: Precipitation > 0.00, Grade: 0.9285714285714286, Times Used: 14, Condition Weight: 0.004014823965410748
# Condition: epa > 1.07, Grade: 0.4942084940540541, Times Used: 259, Condition Weight: 0.03953057441630637
# Condition: current_defence_rank > 27.50, Grade: 0.45454545454545453, Times Used: 22, Condition Weight: 0.0030883261272390363
# Condition: epa <= 1.07, Grade: 0.43857698750416896, Times Used: 1799, Condition Weight: 0.2436689315997529
# Rule Piece 4
# Condition: score_differential > -14.50, Grade: 0.9661016949152542, Times Used: 177, Condition Weight: 0.052810376775787524
# Condition: epa <= 2.30, Grade: 0.2886178859756098, Times Used: 246, Condition Weight: 0.02192711548795553
# Condition: yardline_100 > 32.50, Grade: 0.3923541244064386, Times Used: 497, Condition Weight: 0.06022235942865966
# Condition: stadium <= 22.50, Grade: 1.0, Times Used: 11, Condition Weight: 0.0033971587399629403
# Condition: score_differential > -25.50, Grade: 0.4861660077470356, Times Used: 253, Condition Weight: 0.03798641135268685
# Condition: yardline_100 <= 32.50, Grade: 0.1282051282051282, Times Used: 78, Condition Weight: 0.0030883261272390363
# Condition: AWAY_day_since_last_game > 5.50, Grade: 0.47619047619047616, Times Used: 21, Condition Weight: 0.0030883261272390363
# Condition: score_differential <= -25.50, Grade: 0.8333333333333334, Times Used: 6, Condition Weight: 0.0015441630636195184
# Condition: stadium > 22.50, Grade: 0.6666666666666666, Times Used: 3, Condition Weight: 0.0006176652254478072
# Condition: offense_formation <= 8.50, Grade: 0.4421175104828388, Times Used: 1719, Condition Weight: 0.23471278583075972
# Condition: offense_formation > 8.50, Grade: 0.3625, Times Used: 80, Condition Weight: 0.008956145768993205
# Condition: score_differential <= -14.50, Grade: 0.2222222219047619, Times Used: 63, Condition Weight: 0.004323656571957999
# Condition: epa > 2.30, Grade: 0.0, Times Used: 2, Condition Weight: 0.0
# Condition: AWAY_day_since_last_game <= 5.50, Grade: 0.0, Times Used: 1, Condition Weight: 0.0
# Rule Piece 5
# Condition: surface_type <= 2.50, Grade: 1.0, Times Used: 168, Condition Weight: 0.05188387893761581
# Condition: game_seconds_remaining <= 2767.50, Grade: 0.9545454545454546, Times Used: 22, Condition Weight: 0.0064854848672019775
# Condition: stadium <= 5.50, Grade: 0.4473684210526316, Times Used: 38, Condition Weight: 0.005250154416306363
# Condition: yardline_100 <= 5.50, Grade: 0.9090909090909091, Times Used: 11, Condition Weight: 0.0030883261272390363
# Condition: DefenseTeam <= 7.50, Grade: 0.5, Times Used: 16, Condition Weight: 0.0024706609017912293
# Condition: current_defence_rank <= 29.50, Grade: 1.0, Times Used: 6, Condition Weight: 0.0018529956763434219
# Condition: current_defence_rank > 29.50, Grade: 0.26666666666666666, Times Used: 15, Condition Weight: 0.0012353304508956147
# Condition: stadium <= 26.00, Grade: 1.0, Times Used: 4, Condition Weight: 0.0012353304508956147
# Condition: surface_type > 2.50, Grade: 0.3333333333333333, Times Used: 9, Condition Weight: 0.0009264978381717109
# Condition: stadium > 24.00, Grade: 1.0, Times Used: 2, Condition Weight: 0.0006176652254478073
# Condition: DefenseTeam > 7.50, Grade: 0.03225806451612903, Times Used: 62, Condition Weight: 0.0006176652254478072
# Condition: stadium > 26.00, Grade: 0.5, Times Used: 2, Condition Weight: 0.00030883261272390367
# Condition: yardline_100 > 5.50, Grade: 0.46694214859504135, Times Used: 242, Condition Weight: 0.03489808522544781
# Condition: offense_formation > 1.00, Grade: 0.49434229173974537, Times Used: 1414, Condition Weight: 0.2158739964546016
# Condition: stadium > 5.50, Grade: 0.3877995638997821, Times Used: 459, Condition Weight: 0.054972205012353295
# Condition: Temperature <= 83.70, Grade: 0.2258064512903226, Times Used: 62, Condition Weight: 0.004323656571957999
# Condition: game_seconds_remaining > 2767.50, Grade: 0.22321428549107145, Times Used: 224, Condition Weight: 0.015441630620753552
# Condition: offense_formation <= 1.00, Grade: 0.2, Times Used: 305, Condition Weight: 0.018838789376158124
# Condition: OffenseTeam <= 29.50, Grade: 0.0, Times Used: 2, Condition Weight: 0.0
# Condition: stadium <= 24.00, Grade: 0.0, Times Used: 1, Condition Weight: 0.0
# Condition: Temperature > 83.70, Grade: 0.0, Times Used: 1, Condition Weight: 0.0
# Condition: OffenseTeam > 29.50, Grade: 0, Times Used: 0, Condition Weight: 0.0
# Rule Piece 6
# Condition: yardline_100 <= 64.50, Grade: 1.0, Times Used: 121, Condition Weight: 0.03736874613959234
# Condition: yardline_100 > 64.50, Grade: 1.0, Times Used: 47, Condition Weight: 0.014515132798023472
# Condition: offensive_predictability > 0.01, Grade: 1.0, Times Used: 21, Condition Weight: 0.006485484867201977
# Condition: score_differential > -1.50, Grade: 1.0, Times Used: 17, Condition Weight: 0.005250154416306362
# Condition: Down <= 3.50, Grade: 1.0, Times Used: 10, Condition Weight: 0.0030883261272390363
# Condition: run_count <= 9.50, Grade: 1.0, Times Used: 8, Condition Weight: 0.0024706609017912293
# Condition: score_differential > -13.50, Grade: 1.0, Times Used: 6, Condition Weight: 0.0018529956763434219
# Condition: season_progression > 0.85, Grade: 1.0, Times Used: 4, Condition Weight: 0.0012353304508956147
# Condition: Temperature > 69.24, Grade: 1.0, Times Used: 3, Condition Weight: 0.0009264978381717109
# Condition: current_defence_rank <= 1.50, Grade: 1.0, Times Used: 2, Condition Weight: 0.0006176652254478073
# Condition: pass_run_ratio > 0.72, Grade: 1.0, Times Used: 1, Condition Weight: 0.00030883261272390367
# Condition: OffenseTeam <= 5.50, Grade: 0.81294964, Times Used: 139, Condition Weight: 0.03489808522544781
# Condition: score_differential > -25.50, Grade: 0.506319703, Times Used: 1345, Condition Weight: 0.21031500943020381
# Condition: home_team_on_defense > 0.50, Grade: 0.4054669699999999, Times Used: 439, Condition Weight: 0.054972205012353295
# Condition: score_differential <= -25.50, Grade: 0.260869565, Times Used: 69, Condition Weight: 0.005558987024397777
# Condition: epa <= 0.25, Grade: 0.233333333, Times Used: 60, Condition Weight: 0.004323656571957999
# Condition: AWAY_day_since_last_game <= 13.50, Grade: 0.225225225, Times Used: 222, Condition Weight: 0.015441630620753552
# Condition: run_count > 17.50, Grade: 0.2, Times Used: 305, Condition Weight: 0.018838789376158124
# Condition: OffenseTeam > 5.50, Grade: 0.0, Times Used: 103, Condition Weight: 0.0
# Condition: current_defence_rank > 1.50, Grade: 0.0, Times Used: 60, Condition Weight: 0.0
# Condition: score_differential <= -1.50, Grade: 0.0, Times Used: 21, Condition Weight: 0.0
# Condition: home_team_on_defense <= 0.50, Grade: 0.0, Times Used: 20, Condition Weight: 0.0
# Condition: season_progression <= 0.85, Grade: 0.0, Times Used: 11, Condition Weight: 0.0
# Condition: run_count > 9.50, Grade: 0.0, Times Used: 8, Condition Weight: 0.0
# Condition: Temperature <= 69.24, Grade: 0.0, Times Used: 6, Condition Weight: 0.0
# Condition: epa > 0.25, Grade: 0.0, Times Used: 2, Condition Weight: 0.0
# Condition: AWAY_day_since_last_game > 13.50, Grade: 0.0, Times Used: 2, Condition Weight: 0.0
# Condition: home_team_on_offense <= 36.50, Grade: 0.0, Times Used: 1, Condition Weight: 0.0
# Condition: pass_run_ratio <= 0.72, Grade: 0.0, Times Used: 1, Condition Weight: 0.0
# Condition: Down > 3.50, Grade: 0.0, Times Used: 1, Condition Weight: 0.0
# Condition: offensive_predictability <= 0.01, Grade: 0.0, Times Used: 1, Condition Weight: 0.0
# Condition: home_team_on_offense > 36.50, Grade: 0, Times Used: 0, Condition Weight: 0.0
# Condition: score_differential <= -13.50, Grade: 0, Times Used: 0, Condition Weight: 0.0
# Condition: run_count <= 17.50, Grade: 0, Times Used: 0, Condition Weight: 0.0
# Condition: season_progression <= 0.09, Grade: 0, Times Used: 0, Condition Weight: 0.0
# Condition: season_progression > 0.09, Grade: 0, Times Used: 0, Condition Weight: 0.0

# %%
rule_condition_cols = [col for col in min_rule_analysis_df.columns if 'Rule Piece' in col]

# Melt df to get conditions in one column
min_rule_analysis_df_melted = min_rule_analysis_df.melt(id_vars=['Rule'], value_vars=rule_condition_cols, 
                      var_name='Rule Piece', value_name='Condition')

# Drop any missing conditions
min_rule_analysis_df_melted = min_rule_analysis_df_melted.dropna(subset=['Condition'])

# Merge with results on the condition
df_combined = min_rule_analysis_df_melted.merge(min_results_df[['Condition', 'Condition Score']], on='Condition', how='left')

# Now group by Rule and sum the Rule Scores
min_rule_scores = df_combined.groupby('Rule')['Condition Score'].sum().reset_index()
min_rule_scores.rename(columns={'Condition Score': 'Total Rule Score'}, inplace=True)

min_rule_scores.to_csv('../../Data/explainability/min_acc_fold/min_rule_scores.csv', index=False)

# %%
#getting average condition score per condition (regardless of branch condition is on)
min_condition_rankings = min_results_df.groupby(['Condition']).agg({'Condition Score': 'mean'}).reset_index().sort_values(by='Condition Score', ascending=False, ignore_index=True)
min_feature_rankings = min_condition_rankings.copy()
min_feature_rankings['Feature'] = min_feature_rankings['Condition'].str.split().str[0]
min_feature_rankings['comparison operator'] = min_feature_rankings['Condition'].str.split().str[1]
min_feature_rankings['threshold'] = min_feature_rankings['Condition'].str.split().str[-1].astype(float)
min_feature_rankings = min_feature_rankings[['Feature', 'comparison operator', 'threshold', 'Condition Score']]
min_feature_rankings = min_feature_rankings.groupby('Feature').agg({'Condition Score' : 'mean'}).reset_index().sort_values(by='Condition Score', ascending=False, ignore_index=True)
min_feature_rankings = min_feature_rankings.rename(columns={'Condition Score' : 'Min Fold Feature Score'})
feature_scores_total = min_feature_rankings['Min Fold Feature Score'].sum()
# min_feature_rankings['Feature Score Normalised'] = min_feature_rankings['Feature Score'] / feature_scores_total
min_feature_rankings
# Out:
#                      Feature  Min Fold Feature Score
# 0           defenders_in_box                0.112410
# 1          offense_formation                0.054375
# 2     game_seconds_remaining                0.041103
# 3               surface_type                0.026096
# 4                        epa                0.022290
# 5               yardline_100                0.021070
# 6         score_differential                0.015366
# 7              Precipitation                0.014372
# 8       home_team_on_defense                0.011145
# 9                OffenseTeam                0.009537
# 10      current_defence_rank                0.008041
# 11                   stadium                0.003685
# 12  offensive_predictability                0.003243
# 13                 run_count                0.001560
# 14                      Down                0.001544
# 15  AWAY_day_since_last_game                0.001237
# 16               DefenseTeam                0.000628
# 17               Temperature                0.000476
# 18        season_progression                0.000309
# 19            pass_run_ratio                0.000154
# 20      home_team_on_offense                0.000000

# %% [markdown]
# # Feature Importance Merging #

# %%
mean_max_merge = pd.merge(mean_feature_rankings, max_feature_rankings, on='Feature', how='outer').fillna(0)
overall_feature_rankings = pd.merge(mean_max_merge, min_feature_rankings, on='Feature', how='outer').fillna(0)

overall_feature_rankings['Total Feature Score'] = overall_feature_rankings['Mean Fold Feature Score'] + overall_feature_rankings['Max Fold Feature Score'] + overall_feature_rankings['Min Fold Feature Score']
total = overall_feature_rankings['Total Feature Score'].sum()
overall_feature_rankings['Normalised Feature Score'] = overall_feature_rankings['Total Feature Score'] / total
overall_feature_rankings = overall_feature_rankings.sort_values(by='Normalised Feature Score', ascending=False, ignore_index=True)
overall_feature_rankings
overall_feature_rankings.to_csv('../../Data/explainability/overall_feature_rankings.csv', index=False)
